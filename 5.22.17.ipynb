# %%
import xml.etree.ElementTree as et
import numpy as np

# %%
#### MAVS 6
#### WARRIORS 9

# %%
tree = et.parse('quarter1.XML')
root = tree.getroot()

time = []

for n in root.iter('moment'):
    time.append((n.attrib['game-clock']))

# %%
xball = []
yball = []
zball = []




for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 0: #position of ball, because ball is always the 11*xth index
            xball.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yball.append((float)(temp[3]))
            zball.append((float)(temp[4]))

# %%
## Player 1 ##

xp1 = []
yp1 = []
zp1 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 1: #position of player, because player is always the 11*xth index
            xp1.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp1.append((float)(temp[3]))
            zp1.append((float)(temp[4]))

# %%
## Player 2 ##

xp2 = []
yp2 = []
zp2 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 2: #position of player, because player is always the 11*xth index
            xp2.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp2.append((float)(temp[3]))
            zp2.append((float)(temp[4]))

# %%
## Player 3 ##

xp3 = []
yp3 = []
zp3 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 3: #position of player, because player is always the 11*xth index
            xp3.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp3.append((float)(temp[3]))
            zp3.append((float)(temp[4]))

# %%
## Player 4 ##

xp4 = []
yp4 = []
zp4 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 4: #position of player, because player is always the 11*xth index
            xp4.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp4.append((float)(temp[3]))
            zp4.append((float)(temp[4]))

# %%
## Player 5 ##

xp5 = []
yp5 = []
zp5 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 5: #position of player, because player is always the 11*xth index
            xp5.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp5.append((float)(temp[3]))
            zp5.append((float)(temp[4]))

# %%
## Player 6 ##
xp6 = []
yp6 = []
zp6 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 6: #position of player, because player is always the 11*xth index
            xp6.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp6.append((float)(temp[3]))
            zp6.append((float)(temp[4]))

# %%
## Player 7 ##
xp7 = []
yp7 = []
zp7 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 7: #position of player, because player is always the 11*xth index
            xp7.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp7.append((float)(temp[3]))
            zp7.append((float)(temp[4]))

# %%
## Player 8 ##
xp8 = []
yp8 = []
zp8 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 8: #position of player, because player is always the 11*xth index
            xp8.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp8.append((float)(temp[3]))
            zp8.append((float)(temp[4]))

# %%
## Player 9 ##
xp9 = []
yp9 = []
zp9 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 9: #position of player, because player is always the 11*xth index
            xp9.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp9.append((float)(temp[3]))
            zp9.append((float)(temp[4]))

# %%
## Player 10 ##
xp10 = []
yp10 = []
zp10 = []


for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if (j)%11 == 10: #position of player, because player is always the 11*xth index
            xp10.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
            yp10.append((float)(temp[3]))
            zp10.append((float)(temp[4]))

# %%
import matplotlib.pylab as plt
from matplotlib import colors as cl
# %matplotlib notebook

plt.figure(figsize=(9,5))

plt.plot(xball,yball,'r-',linewidth=0.3) #ball
plt.plot(xp1,yp1,linewidth = 0.3) #player 1
plt.plot(xp2,yp2,linewidth = 0.3) #player 2
plt.plot(xp3,yp3,linewidth = 0.3) #player 3
plt.plot(xp4,yp4,linewidth = 0.3) #player 4
plt.plot(xp5,yp5,linewidth = 0.3) #player 5
plt.plot(xp6,yp6,linewidth = 0.3) #player 6
plt.plot(xp7,yp7,linewidth = 0.3) #player 7
plt.plot(xp8,yp8,linewidth = 0.3) #player 8
plt.plot(xp9,yp9,linewidth = 0.3) #player 9
plt.plot(xp10,yp10,linewidth = 0.3) #player 10
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#######################################################




def position(filename):
    tree = et.parse(filename)
    root = tree.getroot()
    #print root
    
    xball = []
    yball = []
    zball = []




    for n in root.iter('moment'):
        h = n.attrib['locations']
        h = h.split(";")
    
        for j in range(0,len(h)):
            temp = h[j].split(",")
            if j%11 == 0: #position of ball, because ball is always the 11*xth index
                xball.append((float)(temp[2])) # 2 gives x position, 3 gives y position, 4 gives z position
                yball.append((float)(temp[3]))
                zball.append((float)(temp[4]))
    print zball
    
    
    
#########################################################

# %%
####### Velocity #######
def distance_list(x_2,x_1,y_2,y_1,z_2,z_1):
    dist = 0
    dist += np.sqrt((x_2-x_1)**2 + (y_2-y_1)**2 + (z_2-z_1)**2)
    return dist

# %%
def distance(x,y,z):
    d = []
    for i in range(1,len(x)):
        a = (distance_list(x[i],x[i-1],y[i],y[i-1],z[i],z[i-1]))
        d.append(a)
    return d

# %%
#### 1 foot = 0.3048 meters ####
#### Want velocity in m/s in order to eventually find kinectic energy ####
#### Velocity is off because when people check in, their positions change drastically ####



def velocity(d):
    v = [] 
    for i in range(0,len(d)):
        v.append(d[i]*0.3048/0.04)
        
    return v

# %%
dball = distance(xball, yball, zball)
vball = velocity(dball)

dp1 = distance(xp1,yp1,zp1)
vp1 = velocity(dp1)

dp2 = distance(xp2,yp2,zp2)
vp2 = velocity(dp2)

dp3 = distance(xp3,yp3,zp3)
vp3 = velocity(dp3)

dp4 = distance(xp4,yp4,zp4)
vp4 = velocity(dp4)

dp5 = distance(xp5,yp5,zp5)
vp5 = velocity(dp5)

dp6 = distance(xp6,yp6,zp6)
vp6 = velocity(dp6)

dp7 = distance(xp7,yp7,zp7)
vp7 = velocity(dp7)

dp8 = distance(xp8,yp8,zp8)
vp8 = velocity(dp8)

dp9 = distance(xp9,yp9,zp9)
vp9 = velocity(dp9)

dp10 = distance(xp10,yp10,zp10)
vp10 = velocity(dp10)

# %%
if
# Out:
# 10

# %%
mavs_pg = []
for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 1 and temp[1] not in mavs_pg:
            mavs_pg.append(temp[1])
print mavs_pg
# Out:
# ['3234', '173520', '295809', '65820']

# %%
mavs_sg = []
for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 2 and temp[1] not in mavs_sg and temp[1] not in mavs_pg:
            mavs_sg.append(temp[1])
print mavs_sg
# Out:
# ['463135']

# %%
mavs_sf = []
for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 3 and temp[1] not in mavs_sg and temp[1] not in mavs_pg and temp[1] not in mavs_sf:
            mavs_sf.append(temp[1])
print mavs_sf
# Out:
# ['552336']

# %%
mavs_pf = []
for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 4 and temp[1] not in mavs_sg and temp[1] not in mavs_pg and temp[1] not in mavs_sf and temp[1] not in mavs_pf:
            mavs_pf.append(temp[1])
print mavs_pf
# Out:
# ['699947', '606701']

# %%
mavs_c = []
for n in root.iter('moment'):
    h = n.attrib['locations']
    h = h.split(";")
    
    for j in range(0,len(h)):
        temp = h[j].split(",")
        if j%11 == 5 and temp[1] not in mavs_sg and temp[1] not in mavs_pg and temp[1] not in mavs_sf and temp[1] not in mavs_pf and temp[1] not in mavs_c:
            mavs_c.append(temp[1])
print mavs_c
# Out:
# ['698635', '168051', '253980']

# %%
counter = 0
for i in range(0,len(dp3)):
    if dp3[i] > 8:
        print dp3[i]
# Out:
# 3.07583943672
# 49.7438623001
# 9.26593918181
# 22.5036544997
# 11.4172835425
# 5.60446684291
# 28.2180609673
# 21.1966736258
# 2.37347432133
# 7.93548774415
# 23.1114842971
# 18.4053357377
# 65.7713468374
# 16.8268168245
# 31.5782414188
# 5.66786021544
# 29.1076709142
# 29.1246820865
# 44.9973458422
