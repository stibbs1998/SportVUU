# %%
# 5/23
import xml.etree.ElementTree as et # import etree
import numpy as np
import matplotlib.pylab as plt
# %matplotlib notebook



tree = et.parse('quarter1.XML')
root = tree.getroot()
time = [] 
for n in root.iter('moment'):
    time.append(n.attrib['game-clock'])
bx = []
by = []
bz = [] 

p3234x = []
p3234y = []
p3234z = []
p3234t = []

p295809x = []
p295809y = []
p295809z = []
p295809t = []

p463135x = []
p463135y = []
p463135z = []
p463135t = []

p552336x = []
p552336y = []
p552336z = []
p552336t = []

p698635x = []
p698635y = []
p698635z = []
p698635t = []

p173520x = []
p173520y = []
p173520z = []
p173520t = []

p699947x = []
p699947y = []
p699947z = []
p699947t = []

p65820x = []
p65820y = []
p65820z = []
p65820t = []

p606701x = []
p606701y = []
p606701z = []
p606701t = []

p552309x = []
p552309y = []
p552309z = []
p552309t = []

p922594x = []
p922594y = []
p922594z = []
p922594t = []

p401093x = []
p401093y = []
p401093z = []
p401093t = []

p555263x = []
p555263y = []
p555263z = []
p555263t = []

p214168x = []
p214168y = []
p214168z = []
p214168t = []

p338365x = []
p338365y = []
p338365z = []
p338365t = []

p457611x = []
p457611y = []
p457611z = []
p457611t = []

p468895x = []
p468895y = []
p468895z = []
p468895t = []

p847005x = []
p847005y = []
p847005z = []
p847005t = []

p168051x = []
p168051y = []
p168051z = []
p168051t = []

p333212x = []
p333212y = []
p333212z = []
p333212t = []

p504523x = []
p504523y = []
p504523z = []
p504523t = []

p253980x = []
p253980y = []
p253980z = []
p253980t = []

p57934x = []
p57934y = []
p57934z = []
p57934t = []

p609569x = []
p609569y = []
p609569z = []
p609569t = []

p846499x = []
p846499y = []
p846499z = []
p846499t = []

############ GETS ALL PLAYER POSITIONS AND TIMES ON COURT ###################
def position (filename):
    tree = et.parse(filename)
    root = tree.getroot()
    
    for a in root.iter('sequences'):
        r = (float)(a.attrib['period'])
        
        #r = get(period)
        for b in root.iter('moment'):
        
        
            temp = b.attrib['locations']
            temp = temp.split(";")
            clock = (float)(b.attrib['game-clock'])
            if r == 1:
                clock = abs(clock - 720.0)
            elif r == 2:
                clock = abs(clock - 1440.0)
            elif r == 3:
                clock = abs(clock - 2160.0)
            elif r == 4:
                clock = abs(clock - 2880.0)
    
    
            for i in range(0,len(temp)):
                t = temp[i].split(",")
#       
################ BALL #####################
                if i%11 == 0:
                    bx.append((float)(t[2]))
                    by.append((float)(t[3]))
                    bz.append((float)(t[4]))
                
################# MAVS ####################                
                if (int)(t[1]) == 3234:
                    p3234t.append(clock)
                    p3234x.append((float)(t[2]))
                    p3234y.append((float)(t[3]))
                    p3234z.append((float)(t[4]))
                
                
                elif (int)(t[1]) == 295809:
                    
                    p295809t.append(clock)
                    p295809x.append((float)(t[2]))
                    p295809y.append((float)(t[3]))
                    p295809z.append((float)(t[4]))
                
                elif (int)(t[1]) == 463135:
                    
                    p463135t.append(clock)
                    p463135x.append((float)(t[2]))
                    p463135y.append((float)(t[3]))
                    p463135z.append((float)(t[4]))    

                elif (int)(t[1]) == 698635:
                    
                    p698635t.append(clock)
                    p698635x.append((float)(t[2]))
                    p698635y.append((float)(t[3]))
                    p698635z.append((float)(t[4]))

                elif (int)(t[1]) == 173520:
                   
                    p173520t.append(clock)
                    p173520x.append((float)(t[2]))
                    p173520y.append((float)(t[3]))
                    p173520z.append((float)(t[4]))   

                elif (int)(t[1]) == 699947:
                   
                    p699947t.append(clock)
                    p699947x.append((float)(t[2]))
                    p699947y.append((float)(t[3]))
                    p699947z.append((float)(t[4]))   

                elif (int)(t[1]) == 65820:
                    p65820t.append(clock)
                    p65820x.append((float)(t[2]))
                    p65820y.append((float)(t[3]))
                    p65820z.append((float)(t[4]))

                elif (int)(t[1]) == 606701:
                    p606701t.append(clock)
                    p606701x.append((float)(t[2]))
                    p606701y.append((float)(t[3]))
                    p606701z.append((float)(t[4]))

                elif (int)(t[1]) == 922594:
                    p922594t.append(clock)
                    p922594x.append((float)(t[2]))
                    p922594y.append((float)(t[3]))
                    p922594z.append((float)(t[4]))    

                elif (int)(t[1]) == 552309:
                    p552309t.append(clock)
                    p552309x.append((float)(t[2]))
                    p552309y.append((float)(t[3]))
                    p552309z.append((float)(t[4]))

                elif (int)(t[1]) == 401093:
                    p401093t.append(clock)
                    p401093x.append((float)(t[2]))
                    p401093y.append((float)(t[3]))
                    p401093z.append((float)(t[4]))

                elif (int)(t[1]) == 555263:
                    p555263t.append(clock)
                    p555263x.append((float)(t[2]))
                    p555263y.append((float)(t[3]))
                    p555263z.append((float)(t[4]))

                elif (int)(t[1]) == 552336:
                    p552336t.append(clock)
                    p552336x.append((float)(t[2]))
                    p552336y.append((float)(t[3]))
                    p552336z.append((float)(t[4]))
    ###################### WARRIORS ########################

                elif (int)(t[1]) == 214168:
                    p214168t.append(clock)
                    p214168x.append((float)(t[2]))
                    p214168y.append((float)(t[3]))
                    p214168z.append((float)(t[4]))

                elif (int)(t[1]) == 338365:
                    p338365t.append(clock)
                    p338365x.append((float)(t[2]))
                    p338365y.append((float)(t[3]))
                    p338365z.append((float)(t[4]))

                elif (int)(t[1]) == 457611:
                    p457611t.append(clock)
                    p457611x.append((float)(t[2]))
                    p457611y.append((float)(t[3]))
                    p457611z.append((float)(t[4]))

                elif (int)(t[1]) == 468895:
                    p468895t.append(clock)
                    p468895x.append((float)(t[2]))
                    p468895y.append((float)(t[3]))
                    p468895z.append((float)(t[4]))

                elif (int)(t[1]) == 847005:
                    p847005t.append(clock)
                    p847005x.append((float)(t[2]))
                    p847005y.append((float)(t[3]))
                    p847005z.append((float)(t[4]))

                elif (int)(t[1]) == 168051:
                    p168051t.append(clock)
                    p168051x.append((float)(t[2]))
                    p168051y.append((float)(t[3]))
                    p168051z.append((float)(t[4]))

                elif (int)(t[1]) == 333212:
                    p333212t.append(clock)
                    p333212x.append((float)(t[2]))
                    p333212y.append((float)(t[3]))
                    p333212z.append((float)(t[4]))

                elif (int)(t[1]) == 504523:
                    p504523t.append(clock)
                    p504523x.append((float)(t[2]))
                    p504523y.append((float)(t[3]))
                    p504523z.append((float)(t[4]))

                elif (int)(t[1]) == 253980:
                    p253980t.append(clock)
                    p253980x.append((float)(t[2]))
                    p253980y.append((float)(t[3]))
                    p253980z.append((float)(t[4]))

                elif (int)(t[1]) == 57934:
                    p57934t.append(clock)
                    p57934x.append((float)(t[2]))
                    p57934y.append((float)(t[3]))
                    p57934z.append((float)(t[4]))

                elif (int)(t[1]) == 609569:
                    p609569t.append(clock)
                    p609569x.append((float)(t[2]))
                    p609569y.append((float)(t[3]))
                    p609569z.append((float)(t[4]))

                elif (int)(t[1]) == 846499:
                    p846499t.append(clock)
                    p846499x.append((float)(t[2]))
                    p846499y.append((float)(t[3]))
                    p846499z.append((float)(t[4]))



#
#####################################################################
                
position('quarter1.XML')
position('quarter2.XML')
position('quarter3.XML')
position('quarter4.XML')

########## TIME FUNCTION ##################
time_ascending = []

def time(filename):

    tree = et.parse(filename)
    root = tree.getroot()
    
    for b in root.iter('sequences'):
        t = b.attrib['period']
        
    for a in root.iter('moment'):
        r = (float)(a.attrib['game-clock'])
        
        q = r/60.0
        if (float)(t) == 1:
            time_ascending.append(12.0-q)
        elif (float)(t) == 2:
            time_ascending.append(24.0-q)
        elif (float)(t) == 3:
            time_ascending.append(36.0-q)
        elif (float)(t) == 4:
            time_ascending.append(48.0-q)
############################################
time('quarter1.XML')
time('quarter2.XML')
time('quarter3.XML')
time('quarter4.XML')
############################################

# %%
mavsID = []
warriorsID = []

def getPlayerNumbers(filename):
    tree = et.parse(filename)
    root = tree.getroot()
    
    for a in root.iter('moment'):
        temp = a.attrib['locations']
        temp = temp.split(";")
        
    
        t = []
        for i in range(0,len(temp)):
            t = temp[i].split(",")
        
        
            if (int)(t[0]) == 6:
                if (int)(t[1]) not in mavsID:
                    mavsID.append((int)(t[1]))
            elif (int)(t[0]) == 9:
                if (int)(t[1]) not in warriorsID:
                    warriorsID.append((int)(t[1]))

# %%
getPlayerNumbers('quarter1.XML')
getPlayerNumbers('quarter2.XML')
getPlayerNumbers('quarter3.XML')
getPlayerNumbers('quarter4.XML')

# %%
###################### DISTANCE FORMULA ###########################
def distance(x1, x2, y1, y2, z1, z2):
    dis = 0
    dis += np.sqrt((x2 - x1)**2 + (y2 - y1)**2 + (z2-z1)**2) * 0.3048  ### Converts from ft/s ---> m/s ###
    return dis

# %%
##################### TAKES IN 3 LISTS FOR INPUT ##################
def player_distance(x, y, z):
    d = []
    for i in range(0, len(x)):
        d.append(distance(x[i], x[i-1], y[i], y[i-1], z[i], z[i-1]))
    return d
###################################################################
print len(p3234x)
print len(p3234t)
# Out:
# 46865
# 46865

# %%
d = player_distance(p3234x, p3234y, p3234z)
############### FEET PER SECOND #####################
############## VELOCITY FUNCTION ####################
def posToVel(d,t):
    boo = True
    v = []
    holder = []
    for i in range(0, len(d)-2):
        if abs(((float)(t[i+2])-(float)(t[i]))) > .01 and abs(((float)(t[i+2])-(float)(t[i]))) < .09:
            v.append(abs(((float)(d[i+2])-(float)(d[i])/((float)(t[i+2])-(float)(t[i])))))
        else:
            v.append(0)

    if len(v) != len(t):
        del t[0]
        del t[len(t)-1]
####### accounts for outlying points, v > 32 fps ( 22 mph) ############
    for j in range(0,len(v)):
        if v[j] > 10:
                v[j] = v[j-1]



    
        
   
    return v 



# print len(allDistance(p3234x, p3234y, p3234z))
# print len(p3234t)
# print len(p3234x)

print len(p698635t)
print len(p698635x)
print len(p698635y)
print len(p698635z)
# Out:
# 45305
# 45305
# 45305
# 45305

# %%
########## VELOCITY GLOBAL VARIALBES ################
### MAVS ###
p3234v = posToVel(player_distance(p3234x, p3234y, p3234z), p3234t)
p463135v = posToVel(player_distance(p463135x, p463135y, p463135z), p463135t)
p606701v = posToVel(player_distance(p606701x, p606701y, p606701z), p606701t)
p698635v = posToVel(player_distance(p698635x, p698635y, p698635z), p698635t)
p699947v = posToVel(player_distance(p699947x, p699947y, p699947z), p699947t)
p552309v = posToVel(player_distance(p552309x, p552309y, p552309z), p552309t)
p295809v = posToVel(player_distance(p295809x, p295809y, p295809z), p295809t)
p552336v = posToVel(player_distance(p552336x, p552336y, p552336z), p552336t)
p922594v = posToVel(player_distance(p922594x, p922594y, p922594z), p922594t)
p401093v = posToVel(player_distance(p401093x, p401093y, p401093z), p401093t)
p555263v = posToVel(player_distance(p555263x, p555263y, p555263z), p555263t)
p65820v = posToVel(player_distance(p65820x, p65820y, p65820z), p65820t)
p173520v = posToVel(player_distance(p173520x, p173520y, p173520z), p173520t)
# ### DUBS ###
p57934v = posToVel(player_distance(p57934x, p57934y, p57934z), p57934t)
p168051v = posToVel(player_distance(p168051x, p168051y, p168051z), p168051t)
p253980v = posToVel(player_distance(p253980x, p253980y, p253980z), p253980t)
p457611v = posToVel(player_distance(p457611x, p457611y, p457611z), p457611t)
p504523v = posToVel(player_distance(p504523x, p504523y, p504523z), p504523t)
p468895v = posToVel(player_distance(p468895x, p468895y, p468895z), p468895t)
p847005v = posToVel(player_distance(p847005x, p847005y, p847005z), p847005t)
p609569v = posToVel(player_distance(p609569x, p609569y, p609569z), p609569t)
p846499v = posToVel(player_distance(p846499x, p846499y, p846499z), p846499t)
p338365v = posToVel(player_distance(p338365x, p338365y, p338365z), p338365t)
p214168v = posToVel(player_distance(p214168x, p214168y, p214168z), p214168t)
p333212v = posToVel(player_distance(p333212x, p333212y, p333212z), p333212t)


########################################################################

# %%
warriors_vel = [p57934v, p168051v,p214168v, p253980v, p333212v, p338365v, p457611v, p468895v, p504523v, p609569v, p846499v, p847005v]
mavs_vel = [p3234v,p65820v,p173520v,p295809v, p401093v, p463135v, p552309v, p552336v, p555263v, p606701v, p698635v, p699947v, p922594v]
print len(mavs_vel)
# Out:
# 13

# %%
#ttt = np.linspace(0, 48, len(p338365t))
plt.figure(figsize = (10,3))
plt.plot(list(reversed(p338365t)), list(reversed(p338365v)))
plt.title("Steph Curry")
plt.ylabel("Velocity (m/s)")
plt.xlabel("Time")
plt.xlim(0,2880)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# (0, 2880)

# %%
#tt = np.linspace(0, 48, len(p468895t))
plt.figure(figsize = (10,4))
plt.plot(list(reversed(p3234t)), list(reversed(p3234v)))
plt.title("Dirk Nowitzki")
plt.ylabel("Velocity (m/s)")
plt.xlabel("Time")
plt.ylim(0,10)
plt.xlim(0,2880)
for i in range(0, len(p3234v)):
    if p3234v[i] > 20:
        print i
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize = (10,4))
plt.plot(list(reversed(p468895t)), list(reversed(p468895v)))
plt.title("Draymond Green")
plt.ylabel("Velocity (feet/second)")
plt.xlabel("Time")
plt.ylim(0,10)
plt.xlim(0,2880)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# (0, 2880)

# %% [markdown]
# # Mavericks
# |Player Name         | Mass  | Height | Player ID|
# |------------------- | ------| -------| --------|
# |Dirk Nowitzki  | 111.1 kg | 7'0" |3234|
# |Devin Harris| 83.9 kg | 6'3"|65820|
# |J.J. Barea | 83.9 kg | 6'0" |173520|
# |Wesley Matthews | 99.8 kg | 6'5"| 295809|
# |Manny Harris| 83.9 kg| 6'5"|401093|
# |Seth Curry | 83.9 kg | 6'2" |463135|
# |Salah Mejri| 111.1 kg| 7'2" |555263|
# |Dwight Powell| 108.9 kg| 6'11" |552309|
# |Harrison Barnes | 102.1 kg | 6'8" | 552336|
# |Dorian Finney-Smith | 99.8 kg | 6'8"| 606701|
# |Yogi Ferrell | 81.6 kg | 6'0"|698635|
# |Nerlens Noel| 103.4 kg | 6'11"|699947|
# |Nicolas Brussino| 97.5 kg| 6'8"|922594|
# # Warriors ###
# |Player Name          | Mass     |Height| Player ID |
# |--------             | ---------|------| ---------|
# |David West           | 113.4 kg | 6'9" |57934|
# |Matt Barnes          | 102.5 kg | 6'7" |168051|
# |Zaza Pachulia        | 124.7 kg | 6'11"|214168|
# |Shaun Livingston     |  87.1 kg | 6'7" |253980|
# |JaVale McGee         | 122.5 kg | 7'0" |333212|
# |Steph Curry          |  86.2 kg | 6'3" |338365|
# |Klay Thompson        |  97.5 kg | 6'7" |457611|
# |Draymond Green       | 104.3 kg | 6'7" |468895|
# |Ian Clark            |  79.4 kg | 6'3" |504523|
# |James Michael McAdoo | 108.9 kg | 6'9" |609569|
# |Kevon Looney         |  99.8 kg | 6'9" |846499|
# |Patrick McCaw        |  83.9 kg | 6'7" |847005|

# %%
### percent_over_0.5 = 0



def percentage(velocity):
    
    ###################
    
    on_bench = 0
    percent_over_0_5 = 0
    percent_over_1_0 = 0
    percent_over_1_0 = 0
    percent_over_1_5 = 0 
    percent_over_2_0 = 0
    percent_over_2_5 = 0
    percent_over_3_0 = 0
    percent_over_3_5 = 0
    percent_over_4_0 = 0
    ##############################
    for i in range(0,len(velocity)):
        
        if velocity[i]>=4.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            percent_over_3_0 += 1
            percent_over_3_5 += 1
            percent_over_4_0 += 1
        
        elif velocity[i]>= 3.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            percent_over_3_0 += 1
            percent_over_3_5 += 1
            percent_over_4_0 += 1
            percent_over_3_5 += 1
            
        
        elif velocity[i]>= 3.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1            
            percent_over_3_0 += 1
        
        
        
        elif velocity[i]>= 2.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            
            
        elif velocity[i]>= 2.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            
            
        
        elif velocity[i]>= 1.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1 
            

        elif velocity[i]>= 1.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            
            
        elif velocity[i]>= 0.5:
            percent_over_0_5 += 1
            
        elif velocity[i]<= 0.1:
            on_bench += 1
            
        ########################################    
    x = len(velocity) - on_bench
    
    zero_five = 1.0*(float)(percent_over_0_5)/x
    
    one = 1.0*(float)(percent_over_1_0)/x
    one_five = 1.0*(float)(percent_over_1_5)/x
    
    two = 1.0*(float)(percent_over_2_0)/x
    two_five = 1.0*(float)(percent_over_2_5)/x
    
    three = 1.0*(float)(percent_over_3_0)/x
    three_five = 1.0*(float)(percent_over_3_5)/x
    
    four = 1.0*(float)(percent_over_4_0)/(float)(x)

    return zero_five, one, one_five, two, two_five, three, three_five, four

# %%
#########
# Average Velocity #
#########



def avg_vel(velocity):
    total_speed = 0 
    seconds_on_court = 0
    
    for i in range(0,len(velocity)):
        if velocity[i] > 0:
            total_speed += velocity[i]
            seconds_on_court += 1
    
    return (1.0*total_speed/seconds_on_court)

# %%
print "The average velocity of Dirk is %f m/s." %(avg_vel(p3234v))
# Out:
# The average velocity of Dirk is 0.739437 m/s.

# %%
def to_string(velocity):
    if velocity == p57934v:
        return "David West"
    elif velocity == p168051v:
        return "Matt Barnes"
    elif velocity == p214168v:
        return "Zaza Pachulia"
    elif velocity == p253980v:
        return "Shaun Livingston"
    elif velocity == p333212v:
        return "JaVale McGee"
    elif velocity == p338365v:
        return "Steph Curry"
    elif velocity == p457611v:
        return "Klay Thompson"
    elif velocity == p468895v:
        return "Draymond Green"
    elif velocity == p504523v:
        return "Ian Clark"
    elif velocity == p609569v:
        return "J. Michael-McAdoo"
    elif velocity == p846499v:
        return "Kevon Looney"
    elif velocity == p847005v:
        return "Patrick McCaw"
    
    
    ##########################
    elif velocity == p3234v:        
        return "Dirk Nowitzki"
    elif velocity == p65820v:
        return "Devin Harris"
    elif velocity == p173520v:
        return "J.J. Barea"
    elif velocity == p295809v:
        return "W. Matthews"
    elif velocity == p401093v:
        return "Manny Harris"
    elif velocity == p463135v:
        return "Seth Curry"
    elif velocity == p555263v:
        return "Salah Mejri"
    elif velocity == p552309v:
        return "Dwight Powell"
    elif velocity == p552336v:
        return "Harrison Barnes"
    elif velocity == p606701v:
        return "D. Finney-Smith"
    elif velocity == p698635v:
        return "Yogi Ferrell"
    elif velocity == p699947v:
        return "Nerlens Noel"
    elif velocity == p922594v:
        return "Nicolas Brussino"

# %%
def seconds_on_court(velocity):
    
    ###################
    
    on_bench = 0
    percent_over_0_5 = 0
    percent_over_1_0 = 0
    percent_over_1_0 = 0
    percent_over_1_5 = 0 
    percent_over_2_0 = 0
    percent_over_2_5 = 0
    percent_over_3_0 = 0
    percent_over_3_5 = 0
    percent_over_4_0 = 0
    ##############################
    for i in range(0,len(velocity)):
        
        if velocity[i]>=4.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            percent_over_3_0 += 1
            percent_over_3_5 += 1
            percent_over_4_0 += 1
        
        elif velocity[i]>= 3.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            percent_over_3_0 += 1
            percent_over_3_5 += 1
            percent_over_4_0 += 1
            percent_over_3_5 += 1
            
        
        elif velocity[i]>= 3.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1            
            percent_over_3_0 += 1
        
        
        
        elif velocity[i]>= 2.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            percent_over_2_5 += 1
            
            
        elif velocity[i]>= 2.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1
            percent_over_2_0 += 1
            
            
        
        elif velocity[i]>= 1.5:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            percent_over_1_5 += 1 
            

        elif velocity[i]>= 1.0:
            
            percent_over_0_5 += 1
            percent_over_1_0 += 1
            
            
        elif velocity[i]>= 0.5:
            percent_over_0_5 += 1
            
        elif velocity[i]<= 0.1:
            on_bench += 1
            
        ########################################    
    x = 25.00 * 60.00 #25 captures per second, 60 seconds per minute
    
    zero_five = 1.0*(float)(percent_over_0_5)/x
    
    one = 1.0*(float)(percent_over_1_0)/x
    one_five = 1.0*(float)(percent_over_1_5)/x
    
    two = 1.0*(float)(percent_over_2_0)/x
    two_five = 1.0*(float)(percent_over_2_5)/x
    
    three = 1.0*(float)(percent_over_3_0)/x
    three_five = 1.0*(float)(percent_over_3_5)/x
    
    four = 1.0*(float)(percent_over_4_0)/(float)(x)

    return zero_five, one, one_five, two, two_five, three, three_five, four

# %%
# No (0,0) point
# Need 7 x-axis points (1.0,1.5,2.0,2.5,3.0,3.5,4.0)

xdata = np.linspace(0.5,4.0,8)
plt.figure(figsize = (6,4))
for i in range(0,len(warriors_vel)):
    
    ydata = percentage(warriors_vel[i])


    
    plt.plot(xdata,ydata, label = to_string(warriors_vel[i]))
plt.xlabel("Speed (m/s)")
plt.ylabel("Percentage of time speed exceeded")
plt.title("Warriors Percentage")

    
plt.legend(loc = 'upper right')




######## In minutes, not percent ###############


xdata = np.linspace(0.5,4.0,8)
plt.figure()
for i in range(0,len(warriors_vel)):
    
    ydata = seconds_on_court(warriors_vel[i]) # Steph Curry #


    
    plt.plot(xdata,ydata, label = to_string(warriors_vel[i]))
plt.xlabel("Speed (m/s)")
plt.ylabel("Time Speed Exceeded (minutes)")
plt.title("Warriors Time on Court Exceeding Speed")

    
plt.legend(loc = 'upper right')
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="640">

# %%
# No (0,0) point
# Need 7 x-axis points (1.0,1.5,2.0,2.5,3.0,3.5,4.0)

xdata = np.linspace(0.5,4.0,8)
plt.figure()
for i in range(0,len(mavs_vel)):
    
    ydata = percentage(mavs_vel[i])


    
    plt.plot(xdata,ydata, label = to_string(mavs_vel[i]))
plt.xlabel("Speed (m/s)")
plt.ylabel("Percentage of Time Speed Exceeded")
plt.title("Mavs Percentage")

    
plt.legend(loc = 'upper right')




######## In minutes, not percent ###############


xdata = np.linspace(0.5,4.0,8)
plt.figure()
for i in range(0,len(mavs_vel)):
    
    ydata = seconds_on_court(mavs_vel[i]) # Steph Curry #


    
    plt.plot(xdata,ydata, label = to_string(mavs_vel[i]))
plt.xlabel("Speed (m/s)")
plt.ylabel("Time Speed Exceeded (minutes)")
plt.title("Mavs Time on Court Exceeding Speed")

    
plt.legend(loc = 'upper right')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(p3234x, p3234y, linewidth = 0.3)
plt.plot(p295809x, p295809y, linewidth = 0.3)
plt.plot(p463135x, p463135y, linewidth = 0.3)
plt.plot(p606701x, p606701y, linewidth = .3)
plt.plot(p698635x, p698635y, linewidth = .3)
plt.plot(p699947x, p699947y, linewidth = .3)
plt.plot(p552309x, p552309y, linewidth = .3)
plt.plot(p922594x, p922594y, linewidth = .3)
plt.plot(p401093x, p401093y, linewidth = .3)
plt.plot(p555263x, p555263y, linewidth = .3)
plt.plot(p65820x, p65820y, linewidth = .3)
plt.plot(p173520x, p173520y, linewidth = .3)
plt.plot(p552336x, p552336y, linewidth = .3)
plt.title("Mavericks Quarters 1-4")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# print mavsID
# print warriorsID

# %%
plt.figure()
plt.plot(p57934x, p57934y, linewidth = 0.3)
plt.plot(p168051x, p168051y, linewidth = 0.3)
plt.plot(p253980x, p253980y, linewidth = 0.3)
plt.plot(p457611x, p457611y, linewidth = .3)
plt.plot(p504523x, p504523y, linewidth = .3)
plt.plot(p468895x, p468895y, linewidth = .3)
plt.plot(p847005x, p847005y, linewidth = .3)
plt.plot(p609569x, p609569y, linewidth = .3)
plt.plot(p846499x, p846499y, linewidth = .3)
plt.plot(p338365x, p338365y, linewidth = .3)
plt.plot(p214168x, p214168y, linewidth = .3)
plt.plot(p333212x, p333212y, linewidth = .3)

plt.title("Warriors Quarters 1-4")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##############
## Kinectic Energy ##
##############


### First, store masses (in kg) for each player ###

#### Mavs ####

p3234m = 111.1 # Dirk
p65820m = 83.9 # Devin Harris
p173520m = 83.9 # JJ Barea
p295809m = 99.8 # Wesley Matthews
p401093m = 83.9 # Manny Harris
p463135m = 83.9 # Seth Curry

p552309m = 108.9 # Dwight Powell
p552336m = 102.1 # Harrison Barnes
p555263m = 111.1 # Sala Mejri
p606701m = 99.8 # Dorian Finney-Smith
p698635m = 81.6 # Yogi
p699947m = 103.4 # Nerlens Noel
p922594m = 97.5 # Nicolas Brussino

#### Warriors ####
p57934m = 113.4 # David West
p168051m = 102.5 # Matt Barnes
p214168m = 124.7 # Zaza Pachulia
p253980m = 87.1 # Shaun Livingston
p333212m = 122.5 # JaVale McGee
p338365m = 86.2 # Steph Curry
p457611m = 97.5 # Klay Thompson
p468895m = 104.3 # Draymond Green
p504523m = 79.4 # Ian Clark
p609569m = 108.9 # James Michael-McAdoo
p846499m = 99.8 # Kevon Looney
p847005m = 83.9 # Patrick McCaw


### Next, introduce a function to give kinetic energy for a whole game ###

#for i in range(0,len(mavs_vel)):
 #   print "The kinetic energy for %s is %.3f joules." % (to_string(mavs_vel[i]),k_energy())

# %%
mavs_mass = [p3234m,p65820m,p173520m,p295809m,p401093m,p463135m,p552309m,p552336m,p555263m,p606701m,p698635m,p699947m,p922594m]
warriors_mass = [p57934m,p168051m,p214168m,p253980m,p333212m,p338365m,p457611m,p468895m,p504523m,p609569m,p846499m,p847005m]

# %%
def k_energy(velocity,mass): # when entering mass and velocity, make sure player numbers match up!
    #k_instantaneous = []
    #for i in range(0,len(velocity)):
     #   k_instantaneous.append( 0.5 * mass * velocity[i]**2 )
    
    #return k_instantaneous*1.0/len(velocity)
    
    
    counter = []
    
    
    for i in range(0,len(velocity)):
        if velocity[i]>=0:
            
            counter.append(0.5*mass*velocity[i]*velocity[i])
        
    return sum(counter)

# %%
mavs_energy = []

for i in range(0,len(mavs_vel)):
    mavs_energy.append(k_energy(mavs_vel[i],mavs_mass[i]))
    print "The kinetic energy for %s is %.3f joules. \n" % (to_string(mavs_vel[i]), k_energy(mavs_vel[i],mavs_mass[i]))
    

    
##################################


def calories(energy):
    c = energy/4148.00 # 1 food calorie
    
    return c
# Out:
# The kinetic energy for Dirk Nowitzki is 1875948.743 joules.
#
# The kinetic energy for Devin Harris is 1078139.357 joules.
#
# The kinetic energy for J.J. Barea is 1282063.988 joules.
#
# The kinetic energy for W. Matthews is 2824167.376 joules.
#
# The kinetic energy for Manny Harris is 328834.653 joules.
#
# The kinetic energy for Seth Curry is 2308325.503 joules.
#
# The kinetic energy for Dwight Powell is 890932.931 joules.
#
# The kinetic energy for Harrison Barnes is 3141565.475 joules.
#
# The kinetic energy for Salah Mejri is 753116.382 joules.
#
# The kinetic energy for D. Finney-Smith is 1518824.381 joules.
#
# The kinetic energy for Yogi Ferrell is 2037953.482 joules.
#
# The kinetic energy for Nerlens Noel is 1644065.198 joules.
#
# The kinetic energy for Nicolas Brussino is 544091.405 joules.

# %%
mavs_calories = []
for i in range(0,len(mavs_energy)):
    mavs_calories.append(calories(mavs_energy[i]))
    
    print "The calories burned for %s is %.3f calories. \n" % (to_string(mavs_vel[i]),calories(mavs_energy[i]))
# Out:
# The calories burned for Dirk Nowitzki is 452.254 calories.
#
# The calories burned for Devin Harris is 259.918 calories.
#
# The calories burned for J.J. Barea is 309.080 calories.
#
# The calories burned for W. Matthews is 680.850 calories.
#
# The calories burned for Manny Harris is 79.275 calories.
#
# The calories burned for Seth Curry is 556.491 calories.
#
# The calories burned for Dwight Powell is 214.786 calories.
#
# The calories burned for Harrison Barnes is 757.369 calories.
#
# The calories burned for Salah Mejri is 181.561 calories.
#
# The calories burned for D. Finney-Smith is 366.158 calories.
#
# The calories burned for Yogi Ferrell is 491.310 calories.
#
# The calories burned for Nerlens Noel is 396.351 calories.
#
# The calories burned for Nicolas Brussino is 131.170 calories.

# %%
warriors_energy = []

for i in range(0,len(warriors_vel)):
    warriors_energy.append(k_energy(warriors_vel[i],warriors_mass[i]))
    print "The kinetic energy for %s is %.3f joules. \n" % (to_string(warriors_vel[i]), k_energy(warriors_vel[i],warriors_mass[i]))
    

    
##################################
# Out:
# The kinetic energy for David West is 1224829.794 joules.
#
# The kinetic energy for Matt Barnes is 2041559.151 joules.
#
# The kinetic energy for Zaza Pachulia is 1398670.991 joules.
#
# The kinetic energy for Shaun Livingston is 1347653.494 joules.
#
# The kinetic energy for JaVale McGee is 1087116.312 joules.
#
# The kinetic energy for Steph Curry is 2368679.612 joules.
#
# The kinetic energy for Klay Thompson is 2750787.879 joules.
#
# The kinetic energy for Draymond Green is 2178267.623 joules.
#
# The kinetic energy for Ian Clark is 1953913.680 joules.
#
# The kinetic energy for J. Michael-McAdoo is 502385.330 joules.
#
# The kinetic energy for Kevon Looney is 284354.503 joules.
#
# The kinetic energy for Patrick McCaw is 2218300.350 joules.

# %%
warriors_calories = []
for i in range(0,len(warriors_energy)):
    warriors_calories.append(calories(warriors_energy[i]))
    print "%s burned %.3f calories in this game. \n" %(to_string(warriors_vel[i]), calories(warriors_energy[i]))
# Out:
# David West burned 295.282 calories in this game.
#
# Matt Barnes burned 492.179 calories in this game.
#
# Zaza Pachulia burned 337.192 calories in this game.
#
# Shaun Livingston burned 324.892 calories in this game.
#
# JaVale McGee burned 262.082 calories in this game.
#
# Steph Curry burned 571.041 calories in this game.
#
# Klay Thompson burned 663.160 calories in this game.
#
# Draymond Green burned 525.137 calories in this game.
#
# Ian Clark burned 471.050 calories in this game.
#
# J. Michael-McAdoo burned 121.115 calories in this game.
#
# Kevon Looney burned 68.552 calories in this game.
#
# Patrick McCaw burned 534.788 calories in this game.

# %%
# print p3234t

# %%
def power(velocity,mass): # when entering mass and velocity, make sure player numbers match up!
    holder = []
    k_instantaneous = []
    ticks = 0
    for i in range(0,len(velocity)):
        
        holder.append( 0.5 * mass * velocity[i]**2 )
        ticks += 1
        if ticks == 25:
            x = float(sum(holder)/len(holder))
            k_instantaneous.append(x)
            
            
            holder = []
            ticks = 0
        
    return k_instantaneous

# %%
energy1 = power(p3234v,p3234m)
# print sum(energy1)



plt.figure(figsize = (8,4))


x = np.linspace(0,len(energy1),len(energy1))

plt.plot(x,energy1)

plt.xlabel('Time Played (s)')

plt.ylabel('Power Exerted (Watts)')



plt.title('Power')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
mavs_power = []
warriors_power = []


for i in range(0,len(mavs_vel)):
    mavs_power.append(power(mavs_vel[i],mavs_mass[i]))

    
for i in range(0,len(warriors_vel)):
    warriors_power.append(power(warriors_vel[i],warriors_mass[i]))

# %%
def median(list1):
    list2 = sorted(list1)
    
    if len(list2) % 2 == 1:
        ### Odd Number of terms ###
        
        
        length = len(list2)
        mid_index = (length+1)/2  - 1
        return list2[mid_index]
    
    
    elif len(list2) % 2 == 0:
        
        length = len(list2)
        mid_term = (list2[length/2 -1] + list2[(length/2)])/2.0
        
       
        return mid_term

# %%
median(energy1)
# Out:
# 18.34644590235215

# %%
# #### Box and Whisker Plot for Dirk ####


# labels = []

# for i in range(0,len(mavs_vel)):
#     labels.append(to_string(mavs_vel[i]))
    
# data = mavs_power

# # ###basic plot
# plt.figure(figsize = (10,4))
# plt.boxplot(data, labels=labels, vert = False)
# plt.xlabel('Power (Watts)')

# %%
def power_by_min(velocity,mass): # when entering mass and velocity, make sure player numbers match up!
    holder = []
    k_instantaneous = []
    ticks = 0
    for i in range(0,len(velocity)):
        
        holder.append( 0.5 * mass * velocity[i]**2 )
        ticks += 1
        if ticks == 1500:   # the product of 25 times 60 (or 1 minute)
            x = float(sum(holder)/len(holder))
            k_instantaneous.append(x)
            
            
            holder = []
            ticks = 0
        
    return k_instantaneous



mavs_power_minute = []
warriors_power_minute = []


for i in range(0,len(mavs_vel)):
    mavs_power_minute.append(power_by_min(mavs_vel[i],mavs_mass[i]))

    
for i in range(0,len(warriors_vel)):
    warriors_power_minute.append(power_by_min(warriors_vel[i],warriors_mass[i]))
    
# print median(mavs_power_minute[0])

# %%
#### Box and Whisker Plot for Mavericks Power ####



data = mavs_power_minute
labels = []

for i in range(0,len(mavs_vel)):
    labels.append(to_string(mavs_vel[i]))
    




plt.figure(figsize = (10,4))
plt.boxplot(data, labels=labels, vert = False)
plt.xlabel('Power (Watts)')
plt.title('Mavericks Power')




data2 = warriors_power_minute
labels = []

for i in range(0,len(warriors_vel)):
    labels.append(to_string(warriors_vel[i]))
    




plt.figure(figsize = (10,4))
plt.boxplot(data2, labels=labels, vert = False)
plt.xlabel('Power (Watts)')
plt.title('Warriors Power')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
sum_mavs_power_minute = []
for i in range(0,len(mavs_power_minute)):
    avg = sum(mavs_power_minute[i])/len(mavs_power_minute[i])
        
       
    sum_mavs_power_minute.append(avg)
    

mavs_team_power = sum(sum_mavs_power_minute)/len(sum_mavs_power_minute)

# %%
sum_warriors_power_minute = []
for i in range(0,len(warriors_power_minute)):
    avg = sum(warriors_power_minute[i])/len(warriors_power_minute[i])
        
       
    sum_warriors_power_minute.append(avg)
    

warriors_team_power = sum(sum_warriors_power_minute)/len(sum_warriors_power_minute)
    
    
print "The average power exerted for players on the Golden State Warriors is %.3f watts." % (warriors_team_power)
print "\n"
print "The average power exerted for players on the Dallas Mavericks is %.3f watts." % (mavs_team_power)
# Out:
# The average power exerted for players on the Golden State Warriors is 47.548 watts.
#
#
# The average power exerted for players on the Dallas Mavericks is 48.723 watts.

# %%
# """
# =========================
# Simple animation examples
# =========================

# This example contains two animations. The first is a random walk plot. The
# second is an image animation.
# """

# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation


# def update_line(num, data, line):
#     line.set_data(data[..., num])
#     return line,

# fig1 = plt.figure(figsize =(9,4))





# data = np.array([bx,by])
# l, = plt.plot([], [], 'ro', label = 'ball')
# plt.xlim(0, 100)
# plt.ylim(0, 50)
# plt.xlabel('Court')
# plt.title('Ball Position')
# line_ani = animation.FuncAnimation(fig1, update_line, len(bx), fargs=(data, l),
#                                    interval=2, blit=False)

# data2 = np.array([p338365x,p338365y])
# l2, = plt.plot([], [], 'bo', label = 'Steph Curry')
# plt.xlim(0, 100)
# plt.ylim(0, 50)
# plt.xlabel('Court')
# plt.title('Dirk Position')
# line2_ani = animation.FuncAnimation(fig1, update_line, len(p338365x), fargs=(data2, l2),
#                                    interval=2, blit=False)


# plt.legend()

# %%
# """
# =========================
# Simple animation examples
# =========================

# This example contains two animations. The first is a random walk plot. The
# second is an image animation.
# """

# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation


# def update_line(num, data, line):
#     line.set_data(data[..., num])
#     return line,

# fig1 = plt.figure(figsize =(9,4))





# data = np.array([p338365x,p338365y])
# l, = plt.plot([], [], 'bo')
# plt.xlim(0, 100)
# plt.ylim(0, 50)
# plt.xlabel('Court')
# plt.title('Dirk Position')
# line_ani = animation.FuncAnimation(fig1, update_line, len(bx), fargs=(data, l),
#                                    interval=3, blit=False)
